# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
# Import the requests library.
import requests

# Import the API key.
from config2 import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=50aa3fab39ff7d02d7b9bcc2fb53a361

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
city_url = url + "&q=" +"boston"
city_weather = requests.get(city_url).json()

# %%
city_weather
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 40.84,
#   'feels_like': 30.61,
#   'temp_min': 39,
#   'temp_max': 42.8,
#   'pressure': 1017,
#   'humidity': 42},
#  'visibility': 10000,
#  'wind': {'speed': 9.22, 'deg': 340},
#  'clouds': {'all': 75},
#  'dt': 1610479166,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1610453510,
#   'sunset': 1610487184},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
import traceback

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    #print(city_url)

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
  
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print(f"City not found. Skipping...")
        #traceback.print_exc()
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 1 | port hardy
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | turukhansk
# Processing Record 9 of Set 1 | torbay
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | waingapu
# Processing Record 15 of Set 1 | bambous virieux
# Processing Record 16 of Set 1 | leningradskiy
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | hays
# Processing Record 19 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | dudinka
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | iqaluit
# Processing Record 24 of Set 1 | fortuna
# Processing Record 25 of Set 1 | lagoa
# Processing Record 26 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 1 | sanary-sur-mer
# Processing Record 28 of Set 1 | bengkulu
# Processing Record 29 of Set 1 | hualmay
# Processing Record 30 of Set 1 | albox
# Processing Record 31 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 1 | vila franca do campo
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | sola
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | victoria
# Processing Record 37 of Set 1 | mar del plata
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | chuy
# Processing Record 40 of Set 1 | la rioja
# Processing Record 41 of Set 1 | fairbanks
# Processing Record 42 of Set 1 | san cristobal
# Processing Record 43 of Set 1 | road town
# Processing Record 44 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | tasiilaq
# Processing Record 47 of Set 1 | hay river
# Processing Record 48 of Set 1 | husavik
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | ouadda
# Processing Record 2 of Set 2 | geraldton
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | souillac
# Processing Record 5 of Set 2 | upernavik
# Processing Record 6 of Set 2 | pundaguitan
# Processing Record 7 of Set 2 | cayenne
# Processing Record 8 of Set 2 | natal
# Processing Record 9 of Set 2 | yellowknife
# Processing Record 10 of Set 2 | jalu
# Processing Record 11 of Set 2 | winneba
# Processing Record 12 of Set 2 | key largo
# Processing Record 13 of Set 2 | jamestown
# Processing Record 14 of Set 2 | marzuq
# Processing Record 15 of Set 2 | srednekolymsk
# Processing Record 16 of Set 2 | ponta do sol
# Processing Record 17 of Set 2 | riyadh
# Processing Record 18 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 19 of Set 2 | teeli
# Processing Record 20 of Set 2 | deputatskiy
# Processing Record 21 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | dwarka
# Processing Record 24 of Set 2 | dikson
# Processing Record 25 of Set 2 | wilmington
# Processing Record 26 of Set 2 | kununurra
# Processing Record 27 of Set 2 | mbini
# Processing Record 28 of Set 2 | garissa
# Processing Record 29 of Set 2 | ushuaia
# Processing Record 30 of Set 2 | laguna
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | mehran
# Processing Record 33 of Set 2 | avarua
# Processing Record 34 of Set 2 | georgetown
# Processing Record 35 of Set 2 | hobart
# Processing Record 36 of Set 2 | barrow
# Processing Record 37 of Set 2 | banda
# Processing Record 38 of Set 2 | tandil
# Processing Record 39 of Set 2 | chenzhou
# Processing Record 40 of Set 2 | port lincoln
# Processing Record 41 of Set 2 | wrexham
# Processing Record 42 of Set 2 | avera
# Processing Record 43 of Set 2 | saint george
# Processing Record 44 of Set 2 | fallon
# Processing Record 45 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 2 | khatanga
# Processing Record 47 of Set 2 | rio grande
# Processing Record 48 of Set 2 | sao miguel do araguaia
# Processing Record 49 of Set 2 | lusambo
# Processing Record 50 of Set 2 | buala
# Processing Record 1 of Set 3 | tuktoyaktuk
# Processing Record 2 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 3 | nanortalik
# Processing Record 5 of Set 3 | wairoa
# Processing Record 6 of Set 3 | alekseyevsk
# Processing Record 7 of Set 3 | faanui
# Processing Record 8 of Set 3 | kemin
# Processing Record 9 of Set 3 | wadi maliz
# Processing Record 10 of Set 3 | tongliao
# Processing Record 11 of Set 3 | tyler
# Processing Record 12 of Set 3 | saskylakh
# Processing Record 13 of Set 3 | hofn
# Processing Record 14 of Set 3 | airai
# Processing Record 15 of Set 3 | charleston
# Processing Record 16 of Set 3 | esso
# Processing Record 17 of Set 3 | carnarvon
# Processing Record 18 of Set 3 | cidreira
# Processing Record 19 of Set 3 | papar
# Processing Record 20 of Set 3 | nieuw amsterdam
# Processing Record 21 of Set 3 | sarmanovo
# Processing Record 22 of Set 3 | okhotsk
# Processing Record 23 of Set 3 | arraial do cabo
# Processing Record 24 of Set 3 | alwar
# Processing Record 25 of Set 3 | te anau
# Processing Record 26 of Set 3 | lieksa
# Processing Record 27 of Set 3 | poum
# Processing Record 28 of Set 3 | constitucion
# Processing Record 29 of Set 3 | longyearbyen
# Processing Record 30 of Set 3 | krasnoselkup
# Processing Record 31 of Set 3 | ust-nera
# Processing Record 32 of Set 3 | lisakovsk
# Processing Record 33 of Set 3 | pevek
# Processing Record 34 of Set 3 | saint-philippe
# Processing Record 35 of Set 3 | naze
# Processing Record 36 of Set 3 | narsaq
# Processing Record 37 of Set 3 | coihueco
# Processing Record 38 of Set 3 | qaqortoq
# Processing Record 39 of Set 3 | arica
# Processing Record 40 of Set 3 | cabra
# Processing Record 41 of Set 3 | kaitangata
# Processing Record 42 of Set 3 | el astillero
# Processing Record 43 of Set 3 | rongcheng
# Processing Record 44 of Set 3 | luderitz
# Processing Record 45 of Set 3 | chokurdakh
# Processing Record 46 of Set 3 | lujan
# Processing Record 47 of Set 3 | isangel
# Processing Record 48 of Set 3 | nikolskoye
# Processing Record 49 of Set 3 | kavaratti
# Processing Record 50 of Set 3 | korla
# Processing Record 1 of Set 4 | takapau
# Processing Record 2 of Set 4 | east london
# Processing Record 3 of Set 4 | san patricio
# Processing Record 4 of Set 4 | mount isa
# Processing Record 5 of Set 4 | da lat
# Processing Record 6 of Set 4 | lompoc
# Processing Record 7 of Set 4 | noyabrsk
# Processing Record 8 of Set 4 | merauke
# Processing Record 9 of Set 4 | opuwo
# Processing Record 10 of Set 4 | brainerd
# Processing Record 11 of Set 4 | quarai
# Processing Record 12 of Set 4 | sompeta
# Processing Record 13 of Set 4 | tuatapere
# Processing Record 14 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 15 of Set 4 | beringovskiy
# Processing Record 16 of Set 4 | acarau
# Processing Record 17 of Set 4 | puerto ayora
# Processing Record 18 of Set 4 | nhulunbuy
# Processing Record 19 of Set 4 | lumeje
# Processing Record 20 of Set 4 | elizabeth city
# Processing Record 21 of Set 4 | rincon
# Processing Record 22 of Set 4 | kampong chhnang
# Processing Record 23 of Set 4 | vostok
# Processing Record 24 of Set 4 | vestmannaeyjar
# Processing Record 25 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 4 | cherskiy
# Processing Record 27 of Set 4 | maniitsoq
# Processing Record 28 of Set 4 | castro
# Processing Record 29 of Set 4 | rundu
# Processing Record 30 of Set 4 | izhma
# Processing Record 31 of Set 4 | mastic beach
# Processing Record 32 of Set 4 | kasongo-lunda
# Processing Record 33 of Set 4 | cape town
# Processing Record 34 of Set 4 | westport
# Processing Record 35 of Set 4 | mayo
# Processing Record 36 of Set 4 | vila
# Processing Record 37 of Set 4 | lorengau
# Processing Record 38 of Set 4 | bathsheba
# Processing Record 39 of Set 4 | americus
# Processing Record 40 of Set 4 | rio gallegos
# Processing Record 41 of Set 4 | porto santo
# Processing Record 42 of Set 4 | manacapuru
# Processing Record 43 of Set 4 | dunedin
# Processing Record 44 of Set 4 | dhidhdhoo
# Processing Record 45 of Set 4 | burns lake
# Processing Record 46 of Set 4 | conde
# Processing Record 47 of Set 4 | nchelenge
# Processing Record 48 of Set 4 | mahanje
# Processing Record 49 of Set 4 | orleans
# Processing Record 50 of Set 4 | pasni
# Processing Record 1 of Set 5 | buariki
# City not found. Skipping...
# Processing Record 2 of Set 5 | inhambane
# Processing Record 3 of Set 5 | uribia
# Processing Record 4 of Set 5 | ahuimanu
# Processing Record 5 of Set 5 | acapulco
# Processing Record 6 of Set 5 | danli
# Processing Record 7 of Set 5 | kodiak
# Processing Record 8 of Set 5 | kattivakkam
# Processing Record 9 of Set 5 | sarakhs
# Processing Record 10 of Set 5 | birao
# Processing Record 11 of Set 5 | mitu
# Processing Record 12 of Set 5 | suici
# Processing Record 13 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 5 | shakiso
# Processing Record 15 of Set 5 | embonas
# Processing Record 16 of Set 5 | dingle
# Processing Record 17 of Set 5 | naryan-mar
# Processing Record 18 of Set 5 | roald
# Processing Record 19 of Set 5 | mulanur
# Processing Record 20 of Set 5 | sinnamary
# Processing Record 21 of Set 5 | saldanha
# Processing Record 22 of Set 5 | cabo san lucas
# Processing Record 23 of Set 5 | talnakh
# Processing Record 24 of Set 5 | san quintin
# Processing Record 25 of Set 5 | nalut
# Processing Record 26 of Set 5 | benghazi
# Processing Record 27 of Set 5 | cairns
# Processing Record 28 of Set 5 | kaa-khem
# Processing Record 29 of Set 5 | tarakan
# Processing Record 30 of Set 5 | mahebourg
# Processing Record 31 of Set 5 | tromso
# Processing Record 32 of Set 5 | hambantota
# Processing Record 33 of Set 5 | sandavagur
# City not found. Skipping...
# Processing Record 34 of Set 5 | buta
# Processing Record 35 of Set 5 | san ramon
# Processing Record 36 of Set 5 | chicama
# Processing Record 37 of Set 5 | burriana
# Processing Record 38 of Set 5 | loa janan
# Processing Record 39 of Set 5 | plouzane
# Processing Record 40 of Set 5 | sobolevo
# Processing Record 41 of Set 5 | oytal
# Processing Record 42 of Set 5 | detmold
# Processing Record 43 of Set 5 | bethel
# Processing Record 44 of Set 5 | kakamigahara
# Processing Record 45 of Set 5 | seoul
# Processing Record 46 of Set 5 | snezhnogorsk
# Processing Record 47 of Set 5 | manyana
# Processing Record 48 of Set 5 | puerto asis
# Processing Record 49 of Set 5 | forbes
# Processing Record 50 of Set 5 | saint anthony
# Processing Record 1 of Set 6 | houma
# Processing Record 2 of Set 6 | ilulissat
# Processing Record 3 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 6 | costa mesa
# Processing Record 5 of Set 6 | beira
# Processing Record 6 of Set 6 | mayumba
# Processing Record 7 of Set 6 | lata
# Processing Record 8 of Set 6 | abnub
# Processing Record 9 of Set 6 | tiksi
# Processing Record 10 of Set 6 | cardston
# Processing Record 11 of Set 6 | waipawa
# Processing Record 12 of Set 6 | olafsvik
# Processing Record 13 of Set 6 | nome
# Processing Record 14 of Set 6 | batagay
# Processing Record 15 of Set 6 | isla vista
# Processing Record 16 of Set 6 | menongue
# Processing Record 17 of Set 6 | berlevag
# Processing Record 18 of Set 6 | esperance
# Processing Record 19 of Set 6 | flinders
# Processing Record 20 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 6 | touros
# Processing Record 22 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 6 | kidal
# Processing Record 24 of Set 6 | japura
# Processing Record 25 of Set 6 | gat
# Processing Record 26 of Set 6 | nabinagar
# Processing Record 27 of Set 6 | sorland
# Processing Record 28 of Set 6 | jacareacanga
# Processing Record 29 of Set 6 | asau
# Processing Record 30 of Set 6 | zhaotong
# Processing Record 31 of Set 6 | ancud
# Processing Record 32 of Set 6 | gornopravdinsk
# Processing Record 33 of Set 6 | namatanai
# Processing Record 34 of Set 6 | ixtapa
# Processing Record 35 of Set 6 | praia da vitoria
# Processing Record 36 of Set 6 | ongandjera
# Processing Record 37 of Set 6 | libertador general san martin
# Processing Record 38 of Set 6 | tari
# Processing Record 39 of Set 6 | ulverstone
# Processing Record 40 of Set 6 | dombas
# Processing Record 41 of Set 6 | margate
# Processing Record 42 of Set 6 | broome
# Processing Record 43 of Set 6 | parabel
# Processing Record 44 of Set 6 | blythe
# Processing Record 45 of Set 6 | clarence town
# Processing Record 46 of Set 6 | novyy urgal
# Processing Record 47 of Set 6 | vila velha
# Processing Record 48 of Set 6 | blackwater
# Processing Record 49 of Set 6 | caravelas
# Processing Record 50 of Set 6 | ishigaki
# Processing Record 1 of Set 7 | pathardi
# Processing Record 2 of Set 7 | popondetta
# Processing Record 3 of Set 7 | sri aman
# Processing Record 4 of Set 7 | ahipara
# Processing Record 5 of Set 7 | alexandria
# Processing Record 6 of Set 7 | labuhan
# Processing Record 7 of Set 7 | kavieng
# Processing Record 8 of Set 7 | athabasca
# Processing Record 9 of Set 7 | san juan
# Processing Record 10 of Set 7 | lahij
# Processing Record 11 of Set 7 | karratha
# Processing Record 12 of Set 7 | onalaska
# Processing Record 13 of Set 7 | antsohihy
# Processing Record 14 of Set 7 | redmond
# Processing Record 15 of Set 7 | banikoara
# Processing Record 16 of Set 7 | quirinopolis
# Processing Record 17 of Set 7 | swan river
# Processing Record 18 of Set 7 | khambhaliya
# Processing Record 19 of Set 7 | jacmel
# Processing Record 20 of Set 7 | college
# Processing Record 21 of Set 7 | guerrero negro
# Processing Record 22 of Set 7 | morondava
# Processing Record 23 of Set 7 | coquimbo
# Processing Record 24 of Set 7 | torgau
# Processing Record 25 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 7 | omboue
# Processing Record 27 of Set 7 | brigantine
# Processing Record 28 of Set 7 | zhanakorgan
# Processing Record 29 of Set 7 | les cayes
# Processing Record 30 of Set 7 | yakeshi
# Processing Record 31 of Set 7 | luorong
# Processing Record 32 of Set 7 | kopeysk
# Processing Record 33 of Set 7 | mayya
# Processing Record 34 of Set 7 | havoysund
# Processing Record 35 of Set 7 | alofi
# Processing Record 36 of Set 7 | kyshtovka
# Processing Record 37 of Set 7 | kabo
# Processing Record 38 of Set 7 | vanimo
# Processing Record 39 of Set 7 | helena
# Processing Record 40 of Set 7 | barpeta
# Processing Record 41 of Set 7 | la ronge
# Processing Record 42 of Set 7 | guapore
# Processing Record 43 of Set 7 | kruisfontein
# Processing Record 44 of Set 7 | somerset
# Processing Record 45 of Set 7 | port blair
# Processing Record 46 of Set 7 | beyneu
# Processing Record 47 of Set 7 | evans
# Processing Record 48 of Set 7 | hamina
# Processing Record 49 of Set 7 | springville
# Processing Record 50 of Set 7 | sao felix do xingu
# Processing Record 1 of Set 8 | yacuiba
# Processing Record 2 of Set 8 | namibe
# Processing Record 3 of Set 8 | bouca
# Processing Record 4 of Set 8 | codrington
# Processing Record 5 of Set 8 | kismayo
# Processing Record 6 of Set 8 | tautira
# Processing Record 7 of Set 8 | tianpeng
# Processing Record 8 of Set 8 | rosetown
# Processing Record 9 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 8 | kitaibaraki
# Processing Record 11 of Set 8 | matay
# Processing Record 12 of Set 8 | nago
# Processing Record 13 of Set 8 | killybegs
# Processing Record 14 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 8 | pilar
# Processing Record 16 of Set 8 | obigarm
# Processing Record 17 of Set 8 | loandjili
# Processing Record 18 of Set 8 | santa rosa
# Processing Record 19 of Set 8 | harper
# Processing Record 20 of Set 8 | port keats
# Processing Record 21 of Set 8 | tabou
# Processing Record 22 of Set 8 | kaoma
# Processing Record 23 of Set 8 | sabang
# Processing Record 24 of Set 8 | hobbs
# Processing Record 25 of Set 8 | clyde river
# Processing Record 26 of Set 8 | kahului
# Processing Record 27 of Set 8 | bara
# Processing Record 28 of Set 8 | norman wells
# Processing Record 29 of Set 8 | egvekinot
# Processing Record 30 of Set 8 | mana
# Processing Record 31 of Set 8 | qarqin
# Processing Record 32 of Set 8 | butembo
# Processing Record 33 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 8 | belaya gora
# Processing Record 35 of Set 8 | saint-jean-port-joli
# Processing Record 36 of Set 8 | vitim
# Processing Record 37 of Set 8 | mezen
# Processing Record 38 of Set 8 | kijang
# Processing Record 39 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 8 | tual
# Processing Record 41 of Set 8 | del rio
# Processing Record 42 of Set 8 | muros
# Processing Record 43 of Set 8 | port hawkesbury
# Processing Record 44 of Set 8 | kampong cham
# Processing Record 45 of Set 8 | hitoyoshi
# Processing Record 46 of Set 8 | muravlenko
# Processing Record 47 of Set 8 | cururupu
# Processing Record 48 of Set 8 | norrtalje
# Processing Record 49 of Set 8 | murray bridge
# Processing Record 50 of Set 8 | sept-iles
# Processing Record 1 of Set 9 | bonavista
# Processing Record 2 of Set 9 | chapais
# Processing Record 3 of Set 9 | coihaique
# Processing Record 4 of Set 9 | adrar
# Processing Record 5 of Set 9 | mareeba
# Processing Record 6 of Set 9 | alamosa
# Processing Record 7 of Set 9 | umm lajj
# Processing Record 8 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 9 of Set 9 | mehamn
# Processing Record 10 of Set 9 | kauswagan
# Processing Record 11 of Set 9 | ponta delgada
# Processing Record 12 of Set 9 | prince rupert
# Processing Record 13 of Set 9 | kotaparh
# Processing Record 14 of Set 9 | honiara
# Processing Record 15 of Set 9 | kawalu
# Processing Record 16 of Set 9 | roebourne
# Processing Record 17 of Set 9 | paamiut
# Processing Record 18 of Set 9 | diego de almagro
# Processing Record 19 of Set 9 | port hedland
# Processing Record 20 of Set 9 | bonthe
# Processing Record 21 of Set 9 | bakchar
# Processing Record 22 of Set 9 | dong hoi
# Processing Record 23 of Set 9 | safaqis
# City not found. Skipping...
# Processing Record 24 of Set 9 | haines junction
# Processing Record 25 of Set 9 | eureka
# Processing Record 26 of Set 9 | grand gaube
# Processing Record 27 of Set 9 | jacqueville
# Processing Record 28 of Set 9 | innisfail
# Processing Record 29 of Set 9 | denizli
# Processing Record 30 of Set 9 | kurkino
# Processing Record 31 of Set 9 | oussouye
# Processing Record 32 of Set 9 | chachapoyas
# Processing Record 33 of Set 9 | monrovia
# Processing Record 34 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 35 of Set 9 | hervey bay
# Processing Record 36 of Set 9 | bandarbeyla
# Processing Record 37 of Set 9 | murgab
# Processing Record 38 of Set 9 | rognan
# Processing Record 39 of Set 9 | san pedro de ycuamandiyu
# Processing Record 40 of Set 9 | lavrentiya
# Processing Record 41 of Set 9 | ribeira grande
# Processing Record 42 of Set 9 | meulaboh
# Processing Record 43 of Set 9 | campbell river
# Processing Record 44 of Set 9 | mogadishu
# Processing Record 45 of Set 9 | easton
# Processing Record 46 of Set 9 | vao
# Processing Record 47 of Set 9 | lake havasu city
# Processing Record 48 of Set 9 | kashan
# Processing Record 49 of Set 9 | katsuura
# Processing Record 50 of Set 9 | constantine
# Processing Record 1 of Set 10 | samoded
# Processing Record 2 of Set 10 | coari
# Processing Record 3 of Set 10 | pisco
# Processing Record 4 of Set 10 | hede
# Processing Record 5 of Set 10 | aklavik
# Processing Record 6 of Set 10 | tadine
# Processing Record 7 of Set 10 | sitka
# Processing Record 8 of Set 10 | zapolyarnyy
# Processing Record 9 of Set 10 | korem
# Processing Record 10 of Set 10 | gollere
# City not found. Skipping...
# Processing Record 11 of Set 10 | guane
# Processing Record 12 of Set 10 | erenhot
# Processing Record 13 of Set 10 | valera
# Processing Record 14 of Set 10 | ust-maya
# Processing Record 15 of Set 10 | teseney
# Processing Record 16 of Set 10 | kushiro
# Processing Record 17 of Set 10 | diamantino
# Processing Record 18 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 19 of Set 10 | svetlyy
# Processing Record 20 of Set 10 | urucara
# Processing Record 21 of Set 10 | kapit
# Processing Record 22 of Set 10 | kloulklubed
# Processing Record 23 of Set 10 | llallagua
# Processing Record 24 of Set 10 | anadyr
# Processing Record 25 of Set 10 | chimbarongo
# Processing Record 26 of Set 10 | evensk
# Processing Record 27 of Set 10 | kushima
# Processing Record 28 of Set 10 | borlange
# City not found. Skipping...
# Processing Record 29 of Set 10 | karaidel
# Processing Record 30 of Set 10 | male
# Processing Record 31 of Set 10 | aberystwyth
# Processing Record 32 of Set 10 | nyon
# Processing Record 33 of Set 10 | maine-soroa
# Processing Record 34 of Set 10 | takoradi
# Processing Record 35 of Set 10 | conakry
# Processing Record 36 of Set 10 | cooma
# Processing Record 37 of Set 10 | severo-kurilsk
# Processing Record 38 of Set 10 | terney
# Processing Record 39 of Set 10 | honningsvag
# Processing Record 40 of Set 10 | chaumont
# Processing Record 41 of Set 10 | mount gambier
# Processing Record 42 of Set 10 | richards bay
# Processing Record 43 of Set 10 | tigil
# Processing Record 44 of Set 10 | teknaf
# Processing Record 45 of Set 10 | sesheke
# Processing Record 46 of Set 10 | quixeramobim
# Processing Record 47 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 48 of Set 10 | portland
# Processing Record 49 of Set 10 | marsa matruh
# Processing Record 50 of Set 10 | sorata
# Processing Record 1 of Set 11 | oskemen
# Processing Record 2 of Set 11 | aksarka
# Processing Record 3 of Set 11 | artyom
# Processing Record 4 of Set 11 | sovetskiy
# Processing Record 5 of Set 11 | cozumel
# Processing Record 6 of Set 11 | zhanaozen
# Processing Record 7 of Set 11 | nadvoitsy
# Processing Record 8 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 11 | najran
# Processing Record 10 of Set 11 | yulara
# Processing Record 11 of Set 11 | hermiston
# Processing Record 12 of Set 11 | goderich
# Processing Record 13 of Set 11 | hot springs
# Processing Record 14 of Set 11 | pangnirtung
# Processing Record 15 of Set 11 | kapustin yar
# Processing Record 16 of Set 11 | shingu
# Processing Record 17 of Set 11 | komsomolskiy
# Processing Record 18 of Set 11 | klaksvik
# Processing Record 19 of Set 11 | yuanping
# Processing Record 20 of Set 11 | pocone
# Processing Record 21 of Set 11 | ales
# Processing Record 22 of Set 11 | nelson bay
# Processing Record 23 of Set 11 | lashio
# Processing Record 24 of Set 11 | grootfontein
# Processing Record 25 of Set 11 | saint-augustin
# Processing Record 26 of Set 11 | qasigiannguit
# Processing Record 27 of Set 11 | roswell
# Processing Record 28 of Set 11 | itirucu
# Processing Record 29 of Set 11 | solginskiy
# Processing Record 30 of Set 11 | ormara
# Processing Record 31 of Set 11 | mlandizi
# Processing Record 32 of Set 11 | khani
# Processing Record 33 of Set 11 | sim
# Processing Record 34 of Set 11 | ryomgard
# Processing Record 35 of Set 11 | pacific grove
# Processing Record 36 of Set 11 | tanggu
# Processing Record 37 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 11 | imelda
# Processing Record 39 of Set 11 | makubetsu
# Processing Record 40 of Set 11 | galle
# Processing Record 41 of Set 11 | sur
# Processing Record 42 of Set 11 | cockburn town
# Processing Record 43 of Set 11 | binay
# Processing Record 44 of Set 11 | high level
# Processing Record 45 of Set 11 | lazaro cardenas
# Processing Record 46 of Set 11 | campina verde
# Processing Record 47 of Set 11 | nisia floresta
# Processing Record 48 of Set 11 | sao filipe
# Processing Record 49 of Set 11 | sao geraldo do araguaia
# Processing Record 50 of Set 11 | los llanos de aridane
# Processing Record 1 of Set 12 | fort morgan
# Processing Record 2 of Set 12 | mulchen
# Processing Record 3 of Set 12 | eydhafushi
# Processing Record 4 of Set 12 | melito di porto salvo
# Processing Record 5 of Set 12 | semey
# Processing Record 6 of Set 12 | spokane
# Processing Record 7 of Set 12 | sakaiminato
# Processing Record 8 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 9 of Set 12 | katy
# Processing Record 10 of Set 12 | castilho
# Processing Record 11 of Set 12 | vozuca
# Processing Record 12 of Set 12 | hamilton
# Processing Record 13 of Set 12 | pochutla
# Processing Record 14 of Set 12 | asbe teferi
# Processing Record 15 of Set 12 | finale ligure
# Processing Record 16 of Set 12 | ler
# Processing Record 17 of Set 12 | kansay
# City not found. Skipping...
# Processing Record 18 of Set 12 | polis
# Processing Record 19 of Set 12 | ellsworth
# Processing Record 20 of Set 12 | catamarca
# Processing Record 21 of Set 12 | brae
# Processing Record 22 of Set 12 | sombrio
# Processing Record 23 of Set 12 | homer
# Processing Record 24 of Set 12 | capim grosso
# Processing Record 25 of Set 12 | caconda
# Processing Record 26 of Set 12 | barabinsk
# Processing Record 27 of Set 12 | tilichiki
# Processing Record 28 of Set 12 | manggar
# Processing Record 29 of Set 12 | payo
# Processing Record 30 of Set 12 | hami
# Processing Record 31 of Set 12 | tateyama
# Processing Record 32 of Set 12 | jiuquan
# Processing Record 33 of Set 12 | fuyu
# Processing Record 34 of Set 12 | makokou
# Processing Record 35 of Set 12 | paralimni
# Processing Record 36 of Set 12 | san policarpo
# Processing Record 37 of Set 12 | buxar
# Processing Record 38 of Set 12 | maragogi
# Processing Record 39 of Set 12 | coromandel
# Processing Record 40 of Set 12 | nemuro
# Processing Record 41 of Set 12 | susanville
# Processing Record 42 of Set 12 | plettenberg bay
# Processing Record 43 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 44 of Set 12 | allanmyo
# City not found. Skipping...
# Processing Record 45 of Set 12 | muleba
# Processing Record 46 of Set 12 | aras
# Processing Record 47 of Set 12 | bonfim
# Processing Record 48 of Set 12 | makat
# Processing Record 49 of Set 12 | la paz
# Processing Record 50 of Set 12 | zamora
# Processing Record 1 of Set 13 | henties bay
# Processing Record 2 of Set 13 | mogok
# Processing Record 3 of Set 13 | kieta
# Processing Record 4 of Set 13 | marsh harbour
# Processing Record 5 of Set 13 | lafayette
# Processing Record 6 of Set 13 | boa vista
# Processing Record 7 of Set 13 | yvetot
# Processing Record 8 of Set 13 | bilibino
# Processing Record 9 of Set 13 | filingue
# Processing Record 10 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 11 of Set 13 | soyo
# Processing Record 12 of Set 13 | praya
# Processing Record 13 of Set 13 | alta floresta
# Processing Record 14 of Set 13 | sawakin
# Processing Record 15 of Set 13 | tutoia
# Processing Record 16 of Set 13 | la union
# Processing Record 17 of Set 13 | shahr-e babak
# Processing Record 18 of Set 13 | chandler
# Processing Record 19 of Set 13 | el badari
# City not found. Skipping...
# Processing Record 20 of Set 13 | ngunguru
# Processing Record 21 of Set 13 | nouadhibou
# Processing Record 22 of Set 13 | joao camara
# Processing Record 23 of Set 13 | vardo
# Processing Record 24 of Set 13 | phalaborwa
# Processing Record 25 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 13 | saint-paul
# Processing Record 27 of Set 13 | paita
# Processing Record 28 of Set 13 | zubtsov
# Processing Record 29 of Set 13 | jaciara
# Processing Record 30 of Set 13 | turtkul
# City not found. Skipping...
# Processing Record 31 of Set 13 | abha
# Processing Record 32 of Set 13 | gawler
# Processing Record 33 of Set 13 | lishan
# Processing Record 34 of Set 13 | garowe
# Processing Record 35 of Set 13 | bull savanna
# Processing Record 36 of Set 13 | kuching
# Processing Record 37 of Set 13 | tsienyane
# City not found. Skipping...
# Processing Record 38 of Set 13 | jarjis
# City not found. Skipping...
# Processing Record 39 of Set 13 | kalmar
# Processing Record 40 of Set 13 | brownsville
# Processing Record 41 of Set 13 | phan thiet
# Processing Record 42 of Set 13 | pietersburg
# Processing Record 43 of Set 13 | tunduru
# City not found. Skipping...
# Processing Record 44 of Set 13 | tatarsk
# Processing Record 45 of Set 13 | sibu
# Processing Record 46 of Set 13 | shkotovo-26
# City not found. Skipping...
# Processing Record 47 of Set 13 | achisay
# City not found. Skipping...
# Processing Record 48 of Set 13 | takaka
# Processing Record 49 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 13 | lamesa
# Processing Record 1 of Set 14 | camacha
# Processing Record 2 of Set 14 | royan
# Processing Record 3 of Set 14 | ugoofaaru
# Processing Record 4 of Set 14 | beloha
# Processing Record 5 of Set 14 | ratnagiri
# Processing Record 6 of Set 14 | kiama
# Processing Record 7 of Set 14 | champerico
# Processing Record 8 of Set 14 | ilhabela
# Processing Record 9 of Set 14 | mapimi
# Processing Record 10 of Set 14 | anan
# Processing Record 11 of Set 14 | itoman
# Processing Record 12 of Set 14 | kjollefjord
# Processing Record 13 of Set 14 | taoudenni
# Processing Record 14 of Set 14 | lakeway
# Processing Record 15 of Set 14 | gigmoto
# Processing Record 16 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 17 of Set 14 | ostrovnoy
# Processing Record 18 of Set 14 | shenjiamen
# Processing Record 19 of Set 14 | ciudad bolivar
# Processing Record 20 of Set 14 | jardim
# Processing Record 21 of Set 14 | belyy yar
# Processing Record 22 of Set 14 | marquette
# Processing Record 23 of Set 14 | moron
# Processing Record 24 of Set 14 | tura
# Processing Record 25 of Set 14 | palmer
# Processing Record 26 of Set 14 | north bend
# Processing Record 27 of Set 14 | provideniya
# Processing Record 28 of Set 14 | bodden town
# Processing Record 29 of Set 14 | gazipur
# Processing Record 30 of Set 14 | bukoba
# Processing Record 31 of Set 14 | bongandanga
# Processing Record 32 of Set 14 | coruripe
# Processing Record 33 of Set 14 | dodoma
# Processing Record 34 of Set 14 | carauari
# Processing Record 35 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 14 | las vegas
# Processing Record 37 of Set 14 | whitehorse
# Processing Record 38 of Set 14 | the valley
# Processing Record 39 of Set 14 | lerwick
# Processing Record 40 of Set 14 | dickinson
# Processing Record 41 of Set 14 | shakawe
# Processing Record 42 of Set 14 | mahibadhoo
# Processing Record 43 of Set 14 | siklos
# Processing Record 44 of Set 14 | sawankhalok
# Processing Record 45 of Set 14 | zhuhai
# Processing Record 46 of Set 14 | shangrao
# Processing Record 47 of Set 14 | osoyoos
# Processing Record 48 of Set 14 | luanda
# Processing Record 49 of Set 14 | tiarei
# Processing Record 50 of Set 14 | bay roberts
# Processing Record 1 of Set 15 | bima
# Processing Record 2 of Set 15 | baherden
# Processing Record 3 of Set 15 | cam ranh
# Processing Record 4 of Set 15 | ligayan
# Processing Record 5 of Set 15 | paka
# Processing Record 6 of Set 15 | jatiroto
# Processing Record 7 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 15 | general roca
# Processing Record 9 of Set 15 | yusva
# City not found. Skipping...
# Processing Record 10 of Set 15 | hasaki
# Processing Record 11 of Set 15 | tambacounda
# Processing Record 12 of Set 15 | yumen
# Processing Record 13 of Set 15 | pokhara
# Processing Record 14 of Set 15 | tabialan
# City not found. Skipping...
# Processing Record 15 of Set 15 | vung tau
# Processing Record 16 of Set 15 | tecoanapa
# Processing Record 17 of Set 15 | umm jarr
# City not found. Skipping...
# Processing Record 18 of Set 15 | bendigo
# Processing Record 19 of Set 15 | boralday
# Processing Record 20 of Set 15 | giyani
# Processing Record 21 of Set 15 | fond du lac
# Processing Record 22 of Set 15 | thyboron
# Processing Record 23 of Set 15 | kudahuvadhoo
# Processing Record 24 of Set 15 | surt
# Processing Record 25 of Set 15 | dergachi
# Processing Record 26 of Set 15 | nara
# Processing Record 27 of Set 15 | kamenka
# Processing Record 28 of Set 15 | mykolayivka
# Processing Record 29 of Set 15 | vytegra
# Processing Record 30 of Set 15 | ossora
# Processing Record 31 of Set 15 | thunder bay
# Processing Record 32 of Set 15 | dingli
# Processing Record 33 of Set 15 | qabis
# City not found. Skipping...
# Processing Record 34 of Set 15 | yar-sale
# Processing Record 35 of Set 15 | takefu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura      NZ -46.1927  168.8643     55.99        86          84
# 1  Punta Arenas      CL -53.1500  -70.9167     55.40        44           0
# 2    Port Hardy      CA  50.6996 -127.4199     46.40        87          75
# 3         Vaini      TO -21.2000 -175.2000     78.80        94          75
# 4        Albany      US  42.6001  -73.9662     35.01        62          99
# 5        Atuona      PF  -9.8000 -139.0333     77.65        79         100
# 6    Turukhansk      RU  65.8167   87.9833    -15.90        89         100
# 7        Torbay      CA  47.6666  -52.7314     30.99        80          90
# 8      Hermanus      ZA -34.4187   19.2345     71.01        82          86
# 9          Lebu      CL -37.6167  -73.6500     58.51        58           3
#
#    Wind Speed Current Description
# 0        1.01       broken clouds
# 1       28.77           clear sky
# 2        6.91       broken clouds
# 3        6.91       broken clouds
# 4        4.74     overcast clouds
# 5       16.13     overcast clouds
# 6        8.28          light snow
# 7        6.91     overcast clouds
# 8        8.01     overcast clouds
# 9       21.54           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Assignment/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
